# %%
import pandas

# %%
import pandas as pd

# %%
fifa= pd.read_html('https://inside.fifa.com/en/about-fifa/associations/AFC')

# %%
fifa
# Out:
# [                                        0  \
#  0                                     NaN
#  1   Top 20 rankings as of 18 July 2024[1]
#  2                                    Rank
#  3                                       1
#  4                                       2
#  5                                       3
#  6                                       4
#  7                                       5
#  8                                       6
#  9                                       7
#  10                                      8
#  11                                      9
#  12                                     10
#  13                                     11
#  14                                     12
#  15                                     13
#  16                                     14
#  17                                     15
#  18                                     16
#  19                                     17
#  20                                     18
# ...

# %%
fifa[0]
# Out:
#    Rk.                     Team      PTS  +/- pts
# 0  181                 JapanJPN  1628.81    -0.19
# 1   20               IR IranIRN  1611.16     0.16
# 2  231        Korea RepublicKOR  1572.87    -0.13
# 3  241             AustraliaAUS  1571.29     0.29
# 4  341                 QatarQAT  1504.06     0.06
# 5   55                  IraqIRQ  1433.07     0.07
# 6   56          Saudi ArabiaKSA  1431.30     0.30
# 7  611            UzbekistanUZB  1397.41     0.41
# 8   68                JordanJOR  1374.13     0.13
# 9   69  United Arab EmiratesUAE  1368.84    -0.16

# %%
pd.read_excel(r"c:\pandas_docs (2)\pandas_docs\demo1.xlsx",index_col=[5],sheet_name='Sheet4')
# Out:
#          Unnamed: 0  a   b   c   d
# message
# hi                0  1   2   3   4
# world             1  5   6   7   8
# foo               2  9  10  11  12

# %%
titanic=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic(columns=['PassengerId'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[410], line 1
# ----> 1 titanic(columns=['PassengerId'])
#
# TypeError: 'list' object is not callable

# %%
PassengerId
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[412], line 1
# ----> 1 PassengerId
#
# NameError: name 'PassengerId' is not defined
