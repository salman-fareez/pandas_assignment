# %%
import pandas as pd

# %%
survey=pd.read_csv(r"C:\pandas_docs (2)\pandas_docs\survey_results_public.csv")

# %%
sch=pd.read_csv(r"C:\pandas_docs (2)\pandas_docs\survey_results_schema.csv")

# %%
#sch=pd.set_option('display.max_columns',2)

# %%
survey
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %% [markdown]
# - Q2 set respondant columns as index

# %%
survey.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
survey=pd.read_csv(r"C:\pandas_docs (2)\pandas_docs\survey_results_public.csv",index_col='Respondent')

# %% [markdown]
# - Q3 read the first 100 devlprs personal info

# %%
survey
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
survey.loc[:100, ['Age','Gender','Hobbyist','Country','EdLevel','BetterLife','YearsCodePro']]
# Out:
#              Age                                             Gender Hobbyist  \
# Respondent
# 1           14.0                                                Man      Yes
# 2           19.0                                                Man       No
# 3           28.0                                                Man      Yes
# 4           22.0                                                Man       No
# 5           30.0                                                Man      Yes
# ...          ...                                                ...      ...
# 96          43.0                                                Man       No
# 97          25.0  Non-binary, genderqueer, or gender non-conforming      Yes
# 98          30.0                                                Man      Yes
# 99          21.0                                                Man      Yes
# 100         39.0                                              Woman      Yes
#
# ...

# %% [markdown]
# - Q4 1000th devlpr started his coding at the age

# %%
survey.loc[1000,'Age1stCode']
# Out:
# '10'

# %% [markdown]
# - Q5 most used social media of last devlpr in the df

# %%
survey.loc[88882,'SocialMedia']
# Out:
# 'Instagram'

# %% [markdown]
# - Q6 100 to 200 devlprs salary and are they satisfied in their job ?

# %%
survey.loc[100:200,['JobSat','CompTotal']]
# Out:
#                                         JobSat  CompTotal
# Respondent
# 100                             Very satisfied   300000.0
# 101                         Slightly satisfied        NaN
# 102                         Slightly satisfied    67800.0
# 103                                        NaN        NaN
# 104                          Very dissatisfied   155000.0
# ...                                        ...        ...
# 196                          Very dissatisfied    39000.0
# 197                      Slightly dissatisfied    86000.0
# 198                             Very satisfied        NaN
# 199                                        NaN        NaN
# 200         Neither satisfied nor dissatisfied        NaN
#
# [100 rows x 2 columns]

# %% [markdown]
# - Q7 400 to 300 devlprs job satisfaction levle and what are challanges are they facing in thier working palce?

# %%
survey.loc[300:400,['JobSat','WorkChallenge']]
# Out:
#                                         JobSat  \
# Respondent
# 300                                        NaN
# 301                         Slightly satisfied
# 302         Neither satisfied nor dissatisfied
# 303                      Slightly dissatisfied
# 304                             Very satisfied
# ...                                        ...
# 396                             Very satisfied
# 397                                        NaN
# 398                             Very satisfied
# 399                      Slightly dissatisfied
# 400                             Very satisfied
#
#                                                 WorkChallenge
# Respondent
# 300                                                       NaN
# 301         Distracting work environment;Not enough people...
# 302         Inadequate access to necessary tools;Lack of s...
# 303                     Distracting work environment;Meetings
# ...

# %% [markdown]
# - Q8 how long devlpres 100,200,300 work in a week(by hours)

# %%
survey.loc[[100,200,300,]]['WorkWeekHrs']
# Out:
# Respondent
# 100    35.0
# 200    35.0
# 300     NaN
# Name: WorkWeekHrs, dtype: float64

# %% [markdown]
# - Q9 salary of last 100 devlprs and their years of coding experience

# %%
survey.loc[88763:,'YearsCode']
# Out:
# Respondent
# 88763     31
# 88764      4
# 88765      2
# 88766      7
# 88767      5
#         ...
# 88377    NaN
# 88601    NaN
# 88802    NaN
# 88816    NaN
# 88863      8
# Name: YearsCode, Length: 670, dtype: object

# %% [markdown]
# - Q10 how many male and female devlprs are there in the last 100 devlpers

# %%
survey.loc[88763:,'Gender'].value_counts()
# Out:
# Gender
# Man                                                            394
# Woman                                                           66
# Non-binary, genderqueer, or gender non-conforming               11
# Woman;Man                                                        6
# Man;Non-binary, genderqueer, or gender non-conforming            3
# Woman;Non-binary, genderqueer, or gender non-conforming          2
# Woman;Man;Non-binary, genderqueer, or gender non-conforming      1
# Name: count, dtype: int64

# %% [markdown]
# -Q11 how many devlpers are there from india in the first 200 devlprs in list?

# %%
survey.loc[:200,'Country'].value_counts()
# Out:
# Country
# United States             46
# India                     20
# United Kingdom            11
# Germany                   11
# Canada                     9
# Australia                  6
# Netherlands                5
# Spain                      5
# Russian Federation         5
# South Africa               4
# Austria                    4
# Italy                      4
# Argentina                  4
# Poland                     4
# New Zealand                4
# Brazil                     3
# France                     3
# Sweden                     2
# Bosnia and Herzegovina     2
# Croatia                    2
# Estonia                    2
# Pakistan                   2
# Ukraine                    2
# China                      2
# Greece                     2
# Bangladesh                 2
# Malaysia                   2
# Czech Republic             2
# Sri Lanka                  2
# Turkey                     2
# Switzerland                2
# ...

# %% [markdown]
# -Q12 12.Developers whose agest 1st coded and current age from 4000 to 4500

# %%
survey.loc[4000:4500,['Age','Age1stCode']]
# Out:
#              Age Age1stCode
# Respondent
# 4000        25.0         11
# 4001        28.0         14
# 4002        33.0         16
# 4003        17.0         10
# 4004        26.0         14
# ...          ...        ...
# 4496        18.0         15
# 4497        38.0         11
# 4498        27.0         20
# 4499        15.0         14
# 4500         NaN         20
#
# [496 rows x 2 columns]

# %% [markdown]
# -Q13 Salary of 10000 to 11000 and are they have any dependents?

# %%
survey.loc[10000:11000,'Dependents']
# Out:
# Respondent
# 10000     No
# 10001    Yes
# 10002    Yes
# 10003     No
# 10004     No
#         ...
# 10996    Yes
# 10997     No
# 10998    NaN
# 10999    Yes
# 11000     No
# Name: Dependents, Length: 994, dtype: object

# %% [markdown]
# -Q14 salary of the developer 54 is really far from the salary of the 78th developer?

# %%
survey.loc[[54,78],'CompTotal']
# Out:
# Respondent
# 54     51500.0
# 78    550000.0
# Name: CompTotal, dtype: float64

# %% [markdown]
# -Q15 How many unique Ethnicity are there in the devs community?

# %% [markdown]
# -Q15. How many unique Ethnicity are there in the devs community?

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:175, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Ethnicity'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[173], line 1
# ----> 1 survey.loc['Ethnicity']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
# ...

# %%
#b
